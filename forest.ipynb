# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
iris = pd.read_csv("Iris.csv")
iris.drop("Id", axis=1, inplace=True)
iris.head().style.background_gradient(cmap =sns.light_palette("skyblue", as_cmap=True))
# Out:
# <style type="text/css">
# #T_8604d_row0_col0, #T_8604d_row3_col2, #T_8604d_row4_col1 {
#   background-color: #87ceeb;
#   color: #000000;
# }
# #T_8604d_row0_col1 {
#   background-color: #98d4ec;
#   color: #000000;
# }
# #T_8604d_row0_col2, #T_8604d_row1_col2, #T_8604d_row4_col2 {
#   background-color: #bbe0ef;
#   color: #000000;
# }
# #T_8604d_row0_col3, #T_8604d_row1_col1, #T_8604d_row1_col3, #T_8604d_row2_col2, #T_8604d_row2_col3, #T_8604d_row3_col0, #T_8604d_row3_col3, #T_8604d_row4_col3 {
#   background-color: #eff1f2;
#   color: #000000;
# }
# #T_8604d_row1_col0 {
#   background-color: #b1dcee;
#   color: #000000;
# }
# #T_8604d_row2_col0 {
#   background-color: #daeaf1;
#   color: #000000;
# }
# #T_8604d_row2_col1 {
#   background-color: #cce5f0;
#   color: #000000;
# }
# #T_8604d_row3_col1 {
#   background-color: #deebf1;
#   color: #000000;
# }
# #T_8604d_row4_col0 {
#   background-color: #9cd5ec;
#   color: #000000;
# }
# </style>
# <table id="T_8604d">
#   <thead>
# ...

# %%
X = iris.iloc[:,:-1]
y = iris.iloc[:, -1]

# %%
COLOUR_1 = "#3d84ec"
COLOUR_2 = "#008896"
COLOUR_3 = "#2E578B"
COLOUR_SEQUENCE = [COLOUR_1, COLOUR_2, COLOUR_3]

# %%
fig = px.pie(iris, 'Species',color_discrete_sequence=[COLOUR_1, COLOUR_2, COLOUR_3],title='Data Distribution',template='plotly')
fig.show()

# %%
fig = px.box(iris, x="Species", y="SepalLengthCm", color="Species", color_discrete_sequence=COLOUR_SEQUENCE, orientation="v")
fig.show()

# %%
fig = px.histogram(iris, x="SepalLengthCm", color="Species", color_discrete_sequence=COLOUR_SEQUENCE, nbins=50)
fig.show()

# %%
fig = px.box(iris, x="Species", y="SepalWidthCm", color="Species", color_discrete_sequence=COLOUR_SEQUENCE, orientation="v")
fig.show()

# %%
fig = px.histogram(iris, x="SepalWidthCm", color="Species", color_discrete_sequence=COLOUR_SEQUENCE, nbins=30)
fig.show()

# %%
fig = px.box(iris, x="Species", y="PetalLengthCm", color="Species", color_discrete_sequence=COLOUR_SEQUENCE, orientation="v")
fig.show()

# %%
fig = px.histogram(iris, x="PetalLengthCm", color="Species", color_discrete_sequence=COLOUR_SEQUENCE, nbins=30)
fig.show()

# %%
fig = px.box(iris, x="Species", y="PetalWidthCm", color="Species", color_discrete_sequence=COLOUR_SEQUENCE, orientation="v")
fig.show()

# %%
fig = px.histogram(iris, x="PetalWidthCm", color="Species", color_discrete_sequence=COLOUR_SEQUENCE, nbins=30)
fig.show()

# %%
fig = px.scatter(iris, x="SepalLengthCm", y="SepalWidthCm", color="Species", size="PetalLengthCm",template="seaborn", color_discrete_sequence=COLOUR_SEQUENCE)
fig.update_layout(width=800, height=600)
fig.show()

# %%
fig = px.scatter(iris, x="PetalLengthCm", y="PetalWidthCm", color="Species", size="SepalLengthCm",template="seaborn", color_discrete_sequence=COLOUR_SEQUENCE)
fig.update_layout(width=800, height=600)
fig.show()

# %%
iris["Species"] = iris["Species"].astype("category")
codes = iris["Species"].cat.codes

# %%
def train_test_split(X, y, random_state=42, test_size=0.2):
    """
    Splits the data into training and testing sets.

    Parameters:
        X (numpy.ndarray): Features array of shape (n_samples, n_features).
        y (numpy.ndarray): Target array of shape (n_samples,).
        random_state (int): Seed for the random number generator. Default is 42.
        test_size (float): Proportion of samples to include in the test set. Default is 0.2.

    Returns:
        Tuple[numpy.ndarray]: A tuple containing X_train, X_test, y_train, y_test.
    """
    n_samples = X.shape[0]
    np.random.seed(random_state)
    shuffled_indecies = np.random.permutation(np.arange(n_samples))
    test_size = int(n_samples * test_size)
    test_indecies = shuffled_indecies[:test_size]
    train_indecies = shuffled_indecies[test_size:]
    X_trian, X_test = X[train_indecies], X[test_indecies]
    y_train, y_test = y[test_indecies], y[test_indecies]
    return X_trian, X_test, y_train, y_test

# %%
X = iris.iloc[:, :-1].values
y = iris.iloc[:, -1].values.reshape(-1, 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=41, test_size=0.2)
